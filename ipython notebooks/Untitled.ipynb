# %%
import requests
from bs4 import BeautifulSoup

# %%
name='Lionel Messi'
r = requests.get(url="https://www.futbin.com/18/players?page=1&search=%s"%name)

# %%
r.status_code
# Out:
# 200

# %%
r.text[0:500]
# Out:
# '<!DOCTYPE html>\n<!--[if IE 8]>\t\t\t<html class="ie ie8"> <![endif]-->\n<!--[if IE 9]>\t\t\t<html class="ie ie9"> <![endif]-->\n\n<html>\n\n<head>\n\n    <!-- Basic -->\n    <meta http-equiv="Content-Type" content="text/html; charset=utf-8"><script type="text/javascript">(window.NREUM||(NREUM={})).loader_config={xpid:"VQEEU1NaDBADVlhUAQAHXg=="};window.NREUM||(NREUM={}),__nr_require=function(t,n,e){function r(e){if(!n[e]){var o=n[e]={exports:{}};t[e][0].call(o.exports,function(n){var o=t[e][1][n];return r(o||n'

# %%
soup = BeautifulSoup(r.text,'html.parser')

# %%
r = soup.find_all('table',attrs={'class':'table'})

# %%
r[2]
# Out:
# <table class="table table-striped table-hover" id="repTb">
# <thead class="players_table_header">
# <th style="text-align: left; min-width: 257px;">Name</th>
# <th><a data-original-title="Order By Rating" data-placement="top" data-toggle="tooltip" href="/18/players?page=1&amp;search=Lionel%20Messi&amp;sort=Player_Rating&amp;order=desc">RAT</a></th>
# <th><a data-original-title="Order By Position" data-placement="top" data-toggle="tooltip" href="/18/players?page=1&amp;search=Lionel%20Messi&amp;sort=Player_Position&amp;order=desc">POS</a></th>
# <th><a data-original-title="Order By Version" data-placement="top" data-toggle="tooltip" href="/18/players?page=1&amp;search=Lionel%20Messi&amp;sort=version&amp;order=desc">VER</a></th>
# <th><a data-original-title="Order By PS Price" data-placement="top" data-toggle="tooltip" href="/18/players?page=1&amp;search=Lionel%20Messi&amp;sort=ps_price&amp;order=desc">PS</a></th>
# ...

# %%
name = 'Luis Suárez'
url = 'http://www.futhead.com/18/players/?name=%s&sort=vote_sum&bin_platform=ps'%name

# %%
url
# Out:
# 'http://www.futhead.com/18/players/?name=Luis Suárez&sort=vote_sum&bin_platform=ps'

# %%
r = requests.get(url)

# %%
r.text[0:500]
# Out:
# '\n\n<!DOCTYPE html>\n<html lang="en">\n\n<head>\n    <title>FIFA 18 Top Players - Ratings on Ultimate Team - Futhead</title>\n\n    <meta charset="utf-8">\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\n    <meta name="viewport" content="width=device-width, initial-scale=1">\n    <meta name="description" content="Check out all the new top players for FIFA 18 Ultimate, filter results, and add to squads.">\n    <meta name="author" content="Futhead">\n    <meta name="google-site-verification" conten'

# %%
soup = BeautifulSoup(r.text,'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <title>FIFA 18 Top Players - Ratings on Ultimate Team - Futhead</title>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="Check out all the new top players for FIFA 18 Ultimate, filter results, and add to squads." name="description"/>
# <meta content="Futhead" name="author"/>
# <meta content="x1D6UGWhSWXDie5xKmzv5eVsRrzDCCnToL8SMvZrLQk" name="google-site-verification">
# <meta content="Futhead" name="apple-mobile-web-app-title"/>
# <meta content="app-id=943024000" name="apple-itunes-app"/>
# <meta content="app-id=com.curse.futheadmobile" name="google-play-app"/>
# <!-- Themes -->
# <!-- https://developers.google.com/web/fundamentals/design-and-ui/browser-customization/ -->
# <meta content="#940000" name="theme-color"/>
# <meta content="website" property="og:type"/>
# ...

# %%
res = soup.find_all('div',attrs={'class':'content'})

# %%
len(res)
# Out:
# 3

# %%
fir = res[1]
fir
# Out:
# <div class="content player-item font-24">
# <a class="display-block padding-0" href="/18/players/2147/luis-suarez/">
# <span class="player-rating stream-col-50 text-center">
# <span class="revision-gradient shadowed font-12 fut18 gold nif">92</span>
# </span>
# <span class="player-info">
# <img class="player-image" src="http://futhead.cursecdn.com/static/img/18/players/176580.png"/>
# <img class="player-club" src="http://futhead.cursecdn.com/static/img/18/clubs/241.png"/>
# <img class="player-nation" src="http://futhead.cursecdn.com/static/img/18/nations/60.png"/>
# <span class="player-name">Luis Suárez</span>
# <span class="player-club-league-name">
# <strong>ST</strong>
#                          |
#                         FC Barcelona
#                          |
#                         LaLiga Santander
#                     </span>
# </span>
# <span class="player-right text-center hidden-xs">
# ...

# %%
f_rating = int(fir.select('span')[1].text)
f_rating
# Out:
# 92

# %%
f_pace = int(fir.select('span')[7].text)
f_pace
# Out:
# 82

# %%
f_shooting = int(fir.select('span')[10].text)
f_shooting
# Out:
# 90

# %%
f_passing = int(fir.select('span')[13].text)
f_passing
# Out:
# 79

# %%
f_drib = int(fir.select('span')[16].text)
f_drib
# Out:
# 86

# %%
f_def = int(fir.select('span')[19].text)
f_def
# Out:
# 42

# %%
f_phy = int(fir.select('span')[22].text)
f_phy
# Out:
# 81

# %%
f_wrate = fir.select('span')[34].text
f_wrate
# Out:
# 'High / Medium'

# %%
name = 'Manuel Iturra'
url = 'http://www.futhead.com/18/players/?name=%s&sort=vote_sum&bin_platform=ps'%name  
r = requests.get(url)
soup = BeautifulSoup(r.text,'html.parser')
res = soup.find_all('div',attrs={'class':'content'})
if len(res) != 1:
    fir = res[1]
    f_rating = int(fir.select('span')[1].text)
    f_pace = int(fir.select('span')[7].text)
    f_shooting = int(fir.select('span')[10].text)
    f_passing = int(fir.select('span')[13].text)
    f_drib = int(fir.select('span')[16].text)
    f_def = int(fir.select('span')[19].text)
    f_phy = int(fir.select('span')[22].text)
    f_wrate = fir.select('span')[34].text

    print("Name: "+name+" ,Rating: "+str(f_rating)+" ,Pace: "+str(f_pace)+" ,f_shooting: "+str(f_shooting)+" ,Passing: "+str(f_passing)+" ,Dribbling: "+str(f_drib)+" ,Def: "+str(f_def)+" ,Phy: "+str(f_phy)+" ,wrate: "+str(f_wrate)      )
# Out:
# Name: Manuel Iturra ,Rating: 72 ,Pace: 61 ,f_shooting: 45 ,Passing: 64 ,Dribbling: 67 ,Def: 69 ,Phy: 71 ,wrate: Medium / High

# %%
import pandas as pd

# %%
abc = pd.read_csv('rec.csv',encoding="ISO-8859-1")

# %%
abc.head()
# Out:
#    Unnamed: 0                   Name            Position    Country  Age  \
# 0           0  Martin Aguirregabiria          Right-Back      Spain   21
# 1           1         Jairo Samperio           Left Wing      Spain   24
# 2           2           Lionel Messi          Right Wing  Argentina   30
# 3           3      Antoine Griezmann      Centre-Forward     France   26
# 4           4        Sergio Busquets  Defensive Midfield      Spain   29
#
#                Club  Current_Value  Previous_Value
# 0  Deportivo Alavés       800 Th.                -
# 1     UD Las Palmas    2,00 Mill.     3,00 Mill. 
# 2      FC Barcelona  180,00 Mill.   120,00 Mill. 
# 3   Atlético Madrid  100,00 Mill.    80,00 Mill. 
# 4      FC Barcelona   80,00 Mill.    60,00 Mill. 

# %%
n = abc['Name']

# %%
url = 'http://www.futhead.com/18/players/?name=%s&sort=vote_sum&bin_platform=ps'%name
url
# Out:
# 'http://www.futhead.com/18/players/?name=Manuel Iturra&sort=vote_sum&bin_platform=ps'

# %%
name = 'Cristiano Ronaldo'
url = 'https://tools.wmflabs.org/pageviews/?project=en.wikipedia.org&platform=all-access&agent=user&start=2017-01-06&end=2018-01-01&pages=%s'%name
url
# Out:
# 'https://tools.wmflabs.org/pageviews/?project=en.wikipedia.org&platform=all-access&agent=user&start=2017-01-06&end=2018-01-01&pages=Cristiano Ronaldo'

# %%
headers = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/47.0.2526.106 Safari/537.36'}
r = requests.get(url,headers=headers)

# %%
r.status_code
# Out:
# 200

# %%
r.text[0:500]
# Out:
# '<!-- Pageviews Analysis tool -->\n<!-- Copyright 2016 MusikAnimal -->\n<!DOCTYPE html>\n<html>\n  <head>\n    <script type="text/javascript">\n//<![CDATA[\n   i18nLang = "en";\n   i18nRtl = "";\n  \n//]]>\n</script>\n<meta charset="utf-8">\n<meta content="yes" name="apple-mobile-web-app-capable">\n<meta content="black-translucent" name="apple-mobile-web-app-status-bar-style">\n<meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=0" name="viewport">\n<link rel="shortcut icon" sizes='

# %%
soup = BeautifulSoup(r.text,'html.parser')

# %%
soup
# Out:
# <!-- Pageviews Analysis tool -->
# <!-- Copyright 2016 MusikAnimal -->
# <!DOCTYPE html>
#
# <html>
# <head>
# <script type="text/javascript">
# //<![CDATA[
#    i18nLang = "en";
#    i18nRtl = "";
#
# //]]>
# </script>
# <meta charset="utf-8"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="black-translucent" name="apple-mobile-web-app-status-bar-style"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=0" name="viewport"/>
# <link href="/pageviews/images/favicon.ico?v=2" rel="shortcut icon" sizes="16x16 32x32 48x48 96x96"/>
# <script src="application.js"></script>
# <script src="/pageviews/ad_block_test.js"></script>
# <link href="application.css" rel="stylesheet"/>
# <script type="text/javascript">
# //<![CDATA[
#    // language selector
#    $(document).ready(function() {
#      $('.lang-link').on('click', function(e) {
#        e.preventDefault();
# ...

# %%
r = soup.find_all('div',attrs={'class':'summary-column--container'})

# %%
r
# Out:
# [<div class="summary-column--container">
#  <div class="chart-legend col-lg-12 clearfix"></div>
#  </div>]

# %%
import json

# %%
r = requests.get(url)

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\Users\prabh\Miniconda3\lib\site-packages\selenium\webdriver\common\service.py in start(self)
#      75                                             stderr=self.log_file,
# ---> 76                                             stdin=PIPE)
#      77         except TypeError:
#
# C:\Users\prabh\Miniconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors)
#     706                                 errread, errwrite,
# --> 707                                 restore_signals, start_new_session)
#     708         except:
#
# ...
